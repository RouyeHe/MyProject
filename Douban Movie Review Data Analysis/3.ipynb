# %%
import pandas as pd
df = pd.read_csv('DMSC.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2125056 entries, 0 to 2125055
# Data columns (total 10 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   ID             int64
#  1   Movie_Name_EN  object
#  2   Movie_Name_CN  object
#  3   Crawl_Date     object
#  4   Number         int64
#  5   Username       object
#  6   Date           object
#  7   Star           int64
#  8   Comment        object
#  9   Like           int64
# dtypes: int64(4), object(6)
# memory usage: 162.1+ MB

# %%
df
# Out:
#               ID           Movie_Name_EN Movie_Name_CN  Crawl_Date  Number  \
# 0              0  Avengers Age of Ultron        复仇者联盟2  2017-01-22       1
# 1              1  Avengers Age of Ultron        复仇者联盟2  2017-01-22       2
# 2              2  Avengers Age of Ultron        复仇者联盟2  2017-01-22       3
# 3              3  Avengers Age of Ultron        复仇者联盟2  2017-01-22       4
# 4              4  Avengers Age of Ultron        复仇者联盟2  2017-01-22       5
# ...          ...                     ...           ...         ...     ...
# 2125051  2125051                Zootopia         疯狂动物城  2017-01-04  141196
# 2125052  2125052                Zootopia         疯狂动物城  2017-01-04  141197
# 2125053  2125053                Zootopia         疯狂动物城  2017-01-04  141198
# 2125054  2125054                Zootopia         疯狂动物城  2017-01-04  141199
# 2125055  2125055                Zootopia         疯狂动物城  2017-01-04  141200
#
#         Username        Date  Star  \
# ...

# %%
import pandas as pd
df = pd.read_csv('DMSC.csv')

movie_list = ["七月与安生", "九层妖塔", "何以笙箫默", "你的名字", "十二生肖", "变形金刚4", "后会无期", "复仇者联盟", "复仇者联盟2", "夏洛特烦恼", "大圣归来", "大鱼海棠", "寻龙诀", "小时代1", "小时代3", "左耳", "栀子花开", "泰囧"]
df_movies = df[df['Movie_Name_CN'].isin(movie_list)]
df_movies.to_csv('movies.csv', index=Ture)

# %%
"湄公河行动", "爱乐之城", "疯狂动物城", "美人鱼", "美国队长3", "西游伏妖篇", "釜山行", "钢铁侠1", "长城", "西游降魔篇"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2125056 entries, 0 to 2125055
# Data columns (total 10 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   ID             int64
#  1   Movie_Name_EN  object
#  2   Movie_Name_CN  object
#  3   Crawl_Date     object
#  4   Number         int64
#  5   Username       object
#  6   Date           object
#  7   Star           int64
#  8   Comment        object
#  9   Like           int64
# dtypes: int64(4), object(6)
# memory usage: 162.1+ MB
